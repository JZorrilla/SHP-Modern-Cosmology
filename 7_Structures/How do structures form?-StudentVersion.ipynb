# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
from IPython.display import HTML, Image, display
from astropy.cosmology import FlatLambdaCDM

# %% [markdown]
# The content from this lesson is almost exclusively based on Ryden's Introduction to Cosmology

# %% [markdown]
# # Is the universe really homogeneous?

# %% [markdown]
# We saw during the last class how the early universe, as exposed by the CMB was almost, but not perfectly homogeneous. There are small deviations from uniformity, of order $\sim 10^{-5}$. We will not enter now into a discussion of what could be the origin of these inhomogeneities, but rather on its consequences. Could they act as seeds, which eventually grew into the structures we see today?

# %%
Image('cmb.png')

# %% [markdown]
# Also, note that the CMB map does not look as white noise (for those of you who have ever looked at an old tv set this is how white noise looks like: https://www.youtube.com/watch?v=FhXAWTDjjos). It seems that the CMB pattern is dominated by spots for a characteristic size of $\sim 2 \deg$ on the sky ($8 \times 8$ full moons).

# %%
Image('733px-PowerSpectrumExt.png')

# %% [markdown]
# When we measure the 3D position of galaxies on the sky (do you remember how to do this?) we see also that their distribution does not look completely random (Poisson), but there is clustering.

# %%
Image('sdss_pie2.jpg')

# %% [markdown]
# # How do starting inhomogeneities evolve?

# %% [markdown]
# The key mechanism to form structures is GRAVITATIONAL INSTABILITY: in a matter-dominated universe (and we know our universe was matter-dominated for a significant fraction of its life), overdense regions expand less rapidly than the bulk, and if they're dense enough, they can collapse and become gravitationally bound objects, detached from the background expansion.
#
# + Note that we specify the universe has to be matter-dominated, today's universe seems to be dominated by Dark Energy: what would that mean for the growth of structures/

# %% [markdown]
# ## Gravitational collapse: spherical case, static background, pressureless

# %% [markdown]
# We are going to consider the time evolution of a small spherical overdensity. There are two reasons to consider a small inhomogeneity:
#     1. The inhomogeneities in the early universe were small (see CMB)
#     2. This will allow us to use a linear theory (remember: Taylor expansions of functions)
# We will consider spherical geometry because that symmetry will make the math easy

# %% [markdown]
# First, we define the overdensity as the fractional difference to the mean density in the universe:
#
# $\delta\left(\vec{r}, t\right) \equiv \frac{\rho\left(\vec{r},t\right)-\bar{\rho}(t)}{\bar{\rho}(t)},\,\delta \ll1$

# %% [markdown]
# ### Exercise:
#
#  - Write the acceleration experienced by a test particle on the surface of a sphere of radius $R$ with an overdensity $\delta$. Assume the universe is static
#  - Write the equation in a form that looks similar to Friedmann's equation

# %% [markdown]
# ### Exercise:
#
# - Use the conservation of mass within the sphere to obtain an equation that links $R(t)$ with $\delta(t)$
# - Taylor-expand it to get an approximate relationship for small values of the over-density

# %% [markdown]
# ### Exercise:
#
# - Use these relationships to find a differential equation for $\delta (t)$
# - Solve it

# %% [markdown]
# Some comments on the solution:
# - The existence of two modes (growing and vanishing) is quite common in physical instabilities
# - The solution is only valid until $\delta$ stops being small relative to unity.
# - Note that the dynamical time does not depend on the size of the region, but just on the mean density of the medium

# %% [markdown]
# ## Gravitational collapse: spherical case, static background

# %% [markdown]
# ### Exercise:

# %% [markdown]
# - What is the dynamic time for the air within this class?

# %% [markdown]
# Why does the air in the class does not collapse, killing us all without air? Pressure! As a perturbation grows, increasing the density, so does the pressure, preventing air from collapsing. Pressure cannot build up instantaneously. It propagates by mollecule collisions, and any change propagates at the speed of sound of the medium. The characteristic time for a pressure gradient to propagate across a region of characteristic size $R$ is then:
#
# $t_{p} \approx \frac{R}{c_s}$

# %% [markdown]
# It the region is small enough, by the time it wants to collapse, the pressure gradient builds up and stops it. This happens when the characteristic pressure time is smaller than the characteristic dynamic time. This also defines a maximum characteristic lenght for regions to be able to support themselves through pressure, the Jeans lenght (after Jeans, who studied this type of instabilities):
#
# $t_p \sim t_{dyn} \rightarrow R_J \sim c_s t_{dyn} \sim \frac{c_s}{\sqrt{G \bar{\rho}}}$

# %% [markdown]
# ### Exercise:

# %% [markdown]
# - What is the Jeans' lenght on the earth's atmosphere?

# %% [markdown]
# ## Gravitational collapse: matter-radiation decoupling

# %% [markdown]
# Turns out the dynamic time for small overdensities is of the order of the hubble time. To see that, remember that, from Friedman's equation:
#
# $t_{Hubble}\equiv H^{-1} = \sqrt{\frac{3}{8\pi G \bar{\rho}}}$
#
# which turns out to be:
#
# $t_{Hubble} = \sqrt{3/2}t_{dyn}\sim t_{dyn}$
#
# and the Jeans lenght changes with cosmic time as
#
# $R_J \sim \frac{c_s}{H}$
#
# As the universe slows down, the Jeans lenght increases.

# %% [markdown]
# To be able to say more about the evolution of perturbations, we need to compute the speed of sound. That depens on the equation of state of the component under consideration. For radiation, we have (we will not prove it):
#
# $c_s = \frac{c}{\sqrt{3}}$
#
# independent of any other variable. That means that the Jeans lenght for a gas of photons is roughly:
#
# $R_J^{\gamma}\approx 3 \frac{c}{H}$,
#
# three times the Hubble distance. Smaller perturbations will be pressure-supported, and not grow.

# %% [markdown]
# At the time of last scattering, the Hubble distance was $\frac{c}{H(z_{dec})} \approx 0.2 \, \text{Mpc}$. Prior to that time, photons are coupled to baryons, and they dominate the dynamics of the joint plasma. We can then assume that the presence of baryons does not change the Jeans lenght significanty:
#
# $R_J^{dec}\approx 0.6 \text{Mpc}$
#
# and taking the mean baryon density at that redshift yields a mass withing such a region of $M_J \approx 10^{18} M_{\odot}$.
#
# This mass is huge, bigger than that of any supercluster observed. That means that the structures we see today could not collapse while the baryons were still coupled to the photons, for the radiation pressure was capable of withholding any collapse.

# %% [markdown]
# After decoupling, we need to consider the speed of sound on the baryonic plasma, rather than the speed of sound of the photon gas, to assess the Jeans length:
#
# $c_s = \sqrt{\frac{k T}{mc^2}}c \approx \sqrt{0.26 \text{eV}}{1140 \text{MeV}}c \approx 10^{-5} c$
#
# After decoupling, the speed of sound for the baryonic gas decreases dramatically, and so does the Jeans lenght and mass:
#
# $M_J\approx 10^5 M_{\odot}$
#
# This mass corresponds to a dwarf galaxy. As a result, cosmologically small overdensities cannot be sustained by pressure, due to the slowness of the sound speed, and can start collapsing, to generate graviationally bound objects. As the universe expands, the temperature drops and so does the Jeans mass.

# %% [markdown]
# ## Gravitational collapse: expanding background

# %% [markdown]
# We saw how in the absence of a background expansion, the collapse for an overdensity is exponential. Intuitively, we would expect the evolution to be slower for an overdensity in an expanding universe. Let's see if this is the case. If we restrict our analysis to regions small compared to the Hubble radius, we can use Newtonian physics, which is enough to get some intuition on the collapse:
#
# In an exercise similar to what we did before let's assume that
#
# $\rho(t) = \bar{\rho}(t)(1+\delta(t))$

# %% [markdown]
# ### Exercise:

# %% [markdown]
# - Get the scaling of the radius of a sphere, R with the universe scale factor $a$ and the overdensity $\delta$

# %% [markdown]
# ### Exercise:

# %% [markdown]
# - Compute the differential equation that determines $\delta$

# %% [markdown]
# In this equation, if $\delta=0$ we get the second Friedmann equation for a homogeneous universe. Since that one is satisfied, we can keep only terms of order unity to find the equation followed by the perturbation:
#
# $\ddot{\delta} + 2 H \dot{\delta} = 4 \pi G \bar{\rho} \delta$

# %% [markdown]
# This equation is the same found for the static background case, with an additional term proportional to $H$. This term has the form of a friction in a dynamic system, and will damp the growth of perturbations. Taking into consideration the definition of critical density: $\rho_{crit} = \frac{3H^2}{8\pi G}$ the equation can be written as:
#
# $\ddot{\delta} + 2 H \dot{\delta} - \frac{3}{2}\Omega H^2 \delta = 0$

# %% [markdown]
# ### Exercise

# %% [markdown]
# - During radiation domination $a\propto t^{1/2}$, and $\Omega$ is negligible. How do perturbations grow then?

# %% [markdown]
# During radiation domination, perturbations grow logarithmically, which is a rate slower than linear growth, for instance, and much lower than exponential

# %% [markdown]
# During matter domination, the Hubble rate is:
#
# $H = \frac{\dot{a}}{a} = \frac{2}{3}\frac{t^{-1/3}}{t^{2/3}} = \frac{2}{3t}$
#
# and $\Omega \approx 1$, so
#
# $\ddot{\delta}+\frac{4}{3t}\dot{\delta}-\frac{2}{3t}\delta=0 \rightarrow \delta \approx A t^{2/3} + B t^{-1}$

# %% [markdown]
# We also have a growing and vanishing mode, but in this case they're not exponential. The growth of structures is slowed down relative to the case without expansion, with
#
# $\delta \propto t^{2/3} \propto a(t)$

# %% [markdown]
# In the matter-dominated universe, structures grow at the same rate that the universe expands -> the growth of structure can be used as a measurement for the expansion of the universe and its cosmological components.

# %% [markdown]
# All this discussion breaks when the perturbation stops being small. To continue studying its evolution there are two approaches:
#
# 1. Higher order approximations. Instead of keeping only first order terms in the equations, we can keep more terms. This approach is used in many branches of physics, but interestingly, sometimes (as with LSS) it does not converge as the order of terms considered increases.
#
# 2. Solve numerically the evolution, for instance using N-body codes, that discretize the matter density field in massive particles, and follow their evolution under gravitational interactions.

# %% [markdown]
# # Characterizing the structure of the universe

# %% [markdown]
# The same way that, when discussing the CMB, we talked about the lack of interest (or impossibility) or predicting the precise position of cold/hot spots, and therefore looked for a statistical description of their distribution, which took us to the concept of the power spectrum, we can do the same with the distribution of perturbations.

# %% [markdown]
# Instead of using spherical harmonics, we can just do a 3D fourier transform, since the matter density field is 3-dimensional:
#
# $\delta_k = \frac{1}{V}\int d^3k \delta(\vec{r}) \exp{i\vec{k}\cdot\vec{r}}$
#
# We decompose the "irregular" matter distribution in an (infinite) sum of harmonic waves, each characterized by a wave vector $\vec{k}$. The direction of the vector indicates in which direction the wave would "propagate", while its module give an idea of its scale. Small perturbations (small scales) correspond to large values of $k$, and small values of $k$ correspond to large scale perturbations.

# %% [markdown]
# In the linear regime, the equations are linear, which means that the modes are independent from each other. That means that even if small scales reach $\delta \approx 1$ overdensities, and as a result their evolution cannot be followed with linear theory any more, we can still apply the same equations to larger modes. The largest structures we know today (super-clusters) are just abandoning the linear regime, while galaxies and smaller structures did it a long time ago.

# %% [markdown]
# Since the mean inhomogeneity is zero (by definition) the mean of $\delta$ does not convey any information. The next order statistic would be the variance. This is related to the square of the fourier coefficients, or power spectrum:
#
# $\sigma = \frac{V}{2 \pi^2}\int dk P(k) k^2$

# %% [markdown]
# There are some theories (see class on inflation) that predict
#
# $P(k) \propto k^n$
#
# and observations are consistent with $n=1$. A Poisson distribution would be $n=0$ (flat power spectrum, or white noise). Under such a matter distribution, it can be shown that the variance of mass in a given volume scales as
#
# $\frac{\delta M}{M} \propto M^{-\frac{3+n}{6}}$
#
# so, the smaller the mass, the bigger the relative variance

# %% [markdown]
# ## Shape of the power spectrum

# %% [markdown]
# Even if the initial power spectrum can have a very simple functional form, it can change through cosmic time due to horizon effects:

# %% [markdown]
# From our discussion about gravitational-collapse vs. pressure support, perturbations cannot grow until they become larger than the sound horizon. When the universe is radiation dominated, sound speed is nearly that of light, and that induces a suppression on small scales. That will induce a break in the power-spectrum at a scale of $\approx 0.07 \text{Mpc}^{-1}$.
#
# At recombination there is another transition (for baryons), but baryons only represent a small part of the total mass budget (see class on dark matte

# %%
Image("powerspec.jpg")
